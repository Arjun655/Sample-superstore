# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('D:\\Machine learning\\Exploratory data analysis\\Superstore.csv')

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.isnull().sum() #check for null values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.881415     3.789574     0.156203    28.656896
# std    32063.693350    623.241843     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.514000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.962500     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
for i in data.columns:
    print(i,len(data[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5826
# Quantity 14
# Discount 12
# Profit 7287

# %%
# Exploratory data analysis, # data visualization

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data['Sales'],color='red',label='Sales',shade=True,bw=0.2) # for describe the kernel density estimate is used
                                                                         #,for visualizing the probability desity of continous varible.
sns.kdeplot(data['Profit'],color='Blue',label='Profit',shade=True,bw=0.2)
plt.xlim([-100,1000])
plt.legend()

# %%
sns.pairplot(data,hue='Category') # Number diye je row gulo ache tader graph

# %%
sns.pairplot(data,hue='Sub-Category')

# %%
sns.pairplot(data,hue='Region')

# %%
sns.pairplot(data,hue='Segment')

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023848  0.012761  0.058443 -0.029961
# Sales          -0.023848  1.000000  0.200766 -0.028182  0.479062
# Quantity        0.012761  0.200766  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028182  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479062  0.066253 -0.219487  1.000000

# %%
sns.heatmap(data.corr(), cmap='viridis', annot=True)
# Out:
# <AxesSubplot:>

# %%
fig,axis=plt.subplots(ncols=2, nrows=2, figsize=(12,7))

sns.countplot(data['Category'],ax=axis[0][0])
axis[0][0].set_title('Category',fontsize=25)

sns.countplot(data['Segment'],ax=axis[0][1])
axis[0][1].set_title('Segment',fontsize=25)

sns.countplot(data['Ship Mode'],ax=axis[1][0])
axis[1][0].set_title('Ship Mode',fontsize=25)

sns.countplot(data['Region'],ax=axis[1][1])
axis[1][1].set_title('Region',fontsize=25)

plt.tight_layout()

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['Sub-Category'])
plt.title('Sub-Category',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['State'])
plt.xticks(rotation=90)
plt.title('State',fontsize=15)
# Out:
# Text(0.5, 1.0, 'State')

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['Quantity'])
plt.title('Quantity',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['Discount'])
plt.title('Discount',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Discount')

# %%
# distribution the data using the plot

# %%
fig,axis=plt.subplots(ncols=2,nrows=2,figsize=(10,10))
                      
sns.distplot(data['Sales'],color='red',ax=axis[0][0])
axis[0][0].set_title('Sales Distribution',fontsize=20)
                      
sns.distplot(data['Profit'],color='blue',ax=axis[0][1])
axis[0][1].set_title('Profit Distribution',fontsize=20)
                      
sns.distplot(data['Quantity'],color='green',ax=axis[1][0])
axis[1][0].set_title('Quantity Distribution',fontsize=20)
                      
sns.distplot(data['Discount'],color='black',ax=axis[1][1])
axis[1][1].set_title('Discount Distribution',fontsize=20)

plt.tight_layout()                      
plt.show()

# %%
data['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
data1=data['State'].value_counts()
data1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
data1.plot(kind='bar',figsize=(15,5))
plt.xlabel('States')
plt.ylabel('Frequency/Number of deals') 
           
plt.title('State wise dealings',fontsize=25)
plt.show()

# %%
# deals highest is California
# deals lowest is Wyoming

# %%
data['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %%
# City wise dealings

# %%
data2=data['City'].value_counts()
data2=data2.head(50)

# %%
data2.plot(kind='bar',figsize=(20,10))
plt.xlabel=('City')
plt.ylabel('Frequency/Number of deals')

plt.title('City wise dealings',fontsize=25)
plt.show()

# %%
data['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
data_segment=data.groupby(['Segment'])[['Sales','Discount','Profit']].mean()
data_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.778722  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
data_segment.plot.pie(subplots=True,autopct='%1.1f%%',figsize=(28,25),startangle=90,shadow=True,labels=data_segment.index)

plt.title('Segment wise analysis of sale,discount & profit',color='red',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of sale,discount & profit')

# %%
######### ***Note

# %%
data['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
data_state=data.groupby(['State'])[['Sales','Discount','Profit']].mean()
data_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
data1_state=data_state.sort_values('Profit')

data1_state[['Profit']].plot(kind = 'bar', figsize = (12,10))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel=('Profit per Sate')
plt.xlabel=('States')
plt.show()

# %%
# profit high is Vermont
#profit low is Ohio

# %%
data_state['Sales'].plot(kind='pie',figsize = (20,20),autopct='%1.1f%%',startangle=90,shadow=True)
plt.title('State wise analysis of Sale',fontsize=20) # start angle 90° (Africa) #statewise profit
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sale')

# %%
# statewise discount
data1_state['Discount'].plot(kind='bar',figsize=(18,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %%
# city wise analysis profit
data_city= data.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
data_city = data_city.sort_values('Profit')
data_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.Low Profit
data_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
#2. High Profit
data_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
# QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS

# %%
data_quantity = data.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
data_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.451907  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
#1. sales 2. Discount 3. Profit
data_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                     pctdistance=0.69,
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = data_quantity.index)
plt.title('Quantity wise analysis of Sale, Discount, profit',color='blue',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of Sale, Discount, profit')

# %%
# CATAGORY WISE SALES DISCOUNT AND PROFIT

# %%
data_category = data.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
data_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.835968  0.132323  78.752002

# %%
data_category.plot.pie(subplots=True, figsize=(35, 23), autopct='%1.1f%%', labels = data_category.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
# this pie chart for sale,discount,profit in category .........
#sale e technology high
# discount e furniture high
# profit e technology high

# %%
# Sub-Category wise Sales, Profit and Discount

# %%
data_sub_category = data.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
data_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    216.276539  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
# BASED ON THE SALES

# %%
plt.figure(figsize = (15,15))
plt.pie(data_sub_category['Sales'], labels = data_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', color='red',fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
# copiers has high sales

# %%
# BASED ON THE DISCOUNT

# %%
plt.figure(figsize = (15,15))
plt.pie(data_sub_category['Discount'], labels = data_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis',color='red', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
# binders,machines,tables have high discount

# %%
# BASED ON THE PROFIT

# %%
# profit has negetive values thats why piechart is not p[ossible

# %%
data_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (15,5),
                                                              label=['Avg Sales Price($)','Profit($)'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
# copiers has high profit

# %%
# REGION WISE ANALYSIS

# %%
data_region = data.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
data_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.873393  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
data_region.plot.pie(subplots=True, figsize=(18, 20), autopct='%1.1f%%',labels = data_region.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
#sale e south high
# discount e central high
# profit e west high

# %%
#SHIP MODE WISE ANALYSIS

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
data_shipmode = data.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
data_shipmode.plot.pie(subplots=True,figsize=(18, 20), autopct='%1.1f%%', labels = data_shipmode.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
# shipmode diye sale e same day te sale high
# First class e discount high
# First class e profit high.............

# %%
                                             #end
